# %% [markdown]
# ## Real Estate Sales 2001-2020 Project
# #### The dataset can be found from the  kaggle website.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
Estate = pd.read_csv(r'C:\Users\Michael\Desktop\datasets\Estate_Sales.csv',low_memory =False)

# %%
Estate
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997206         190272       2019    06/24/2020     New London
# 997207         190284       2019    11/27/2019      Waterbury
# 997208         190129       2019    04/27/2020  Windsor Locks
# 997209         190504       2019    06/03/2020     Middletown
# 997210         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value   Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE          150500  325000.00000      0.46300
# ...

# %% [markdown]
# #### Adding Month Column to the data Frame

# %%
Estate['Month'] = Estate['Date Recorded'].str[0:2]
Estate['Month'] = Estate['Month'].astype('int32')
Estate.head()
# Out:
#    Serial Number  List Year Date Recorded     Town                Address  \
# 0        2020348       2020    09/13/2021  Ansonia        230 WAKELEE AVE
# 1          20002       2020    10/02/2020  Ashford        390 TURNPIKE RD
# 2         200212       2020    03/09/2021     Avon       5 CHESTNUT DRIVE
# 3         200243       2020    04/13/2021     Avon  111 NORTHINGTON DRIVE
# 4         200377       2020    07/02/2021     Avon     70 FAR HILLS DRIVE
#
#    Assessed Value   Sale Amount  Sales Ratio Property Type Residential Type  \
# 0          150500  325000.00000      0.46300    Commercial              NaN
# 1          253000  430000.00000      0.58830   Residential    Single Family
# 2          130400  179900.00000      0.72480   Residential            Condo
# 3          619290  890000.00000      0.69580   Residential    Single Family
# 4          862330 1447500.00000      0.59570   Residential    Single Family
#
#    Month
# 0      9
# 1     10
# 2      3
# 3      4
# 4      7

# %% [markdown]
# #### Swapping The Month Location next after List year

# %%
Estate.insert(2,'Month',Estate.pop('Month'))
Estate
# Out:
#         Serial Number  List Year  Month Date Recorded           Town  \
# 0             2020348       2020      9    09/13/2021        Ansonia
# 1               20002       2020     10    10/02/2020        Ashford
# 2              200212       2020      3    03/09/2021           Avon
# 3              200243       2020      4    04/13/2021           Avon
# 4              200377       2020      7    07/02/2021           Avon
# ...               ...        ...    ...           ...            ...
# 997206         190272       2019      6    06/24/2020     New London
# 997207         190284       2019     11    11/27/2019      Waterbury
# 997208         190129       2019      4    04/27/2020  Windsor Locks
# 997209         190504       2019      6    06/03/2020     Middletown
# 997210         190344       2019     12    12/20/2019        Milford
#
#                       Address  Assessed Value   Sale Amount  Sales Ratio  \
# ...

# %%
Estate.describe()
# Out:
#          Serial Number    List Year        Month  Assessed Value  \
# count     997211.00000 997211.00000 997211.00000    997211.00000
# mean      431187.25405   2010.18985      6.81281    279144.22524
# std      6549225.71449      6.23787      3.23772   1670611.48613
# min           81.00000   2001.00000      1.00000         0.00000
# 25%        30444.00000   2004.00000      4.00000     87600.00000
# 50%        70303.00000   2010.00000      7.00000    138390.00000
# 75%       151878.50000   2016.00000      9.00000    225560.00000
# max   2000500023.00000   2020.00000     12.00000 881510000.00000
#
#            Sale Amount   Sales Ratio
# count     997211.00000  997211.00000
# mean      391151.96803      10.44639
# std      5347275.54558    1890.19369
# min            0.00000       0.00000
# 25%       140000.00000       0.48670
# 50%       225000.00000       0.62460
# 75%       365000.00000       0.78528
# max   5000000000.00000 1226420.00000

# %%
Estate.rename(columns ={'Sale Amount':'Sales Amount'}, inplace = True)

# %%
Estate.columns
# Out:
# Index(['Serial Number', 'List Year', 'Month', 'Date Recorded', 'Town',
#        'Address', 'Assessed Value', 'Sales Amount', 'Sales Ratio',
#        'Property Type', 'Residential Type'],
#       dtype='object')

# %%
# Estates Num of rows and columns
Estate.shape
# Out:
# (997211, 11)

# %%
Estate.nunique()
# Out:
# Serial Number        83536
# List Year               20
# Month                   12
# Date Recorded         6387
# Town                   170
# Address             714371
# Assessed Value       91378
# Sales Amount         57372
# Sales Ratio         547044
# Property Type           12
# Residential Type         7
# dtype: int64

# %%
# Estate Data Types
Estate.dtypes
# Out:
# Serial Number         int64
# List Year             int64
# Month                 int32
# Date Recorded        object
# Town                 object
# Address              object
# Assessed Value        int64
# Sales Amount        float64
# Sales Ratio         float64
# Property Type        object
# Residential Type     object
# dtype: object

# %%
Estate.value_counts()
# Out:
# Serial Number  List Year  Month  Date Recorded  Town        Address                  Assessed Value  Sales Amount  Sales Ratio  Property Type  Residential Type
# 82             2008       10     10/01/2008     Meriden     17 SUNRISE HILL          144210          171000.00000  0.84333      Single Family  Single Family       1
# 160536         2016       9      09/26/2017     Westport    202 BAYBERRY LANE        696100          773500.00000  0.89994      Single Family  Single Family       1
# 160537         2016       1      01/06/2017     Stamford    25 FOREST STREET # 5F    189010          241000.00000  0.78427      Condo          Condo               1
#                                  01/12/2017     Bridgeport  56 ELMSFORD RD           122530          212500.00000  0.57661      Single Family  Single Family       1
#                           3      03/02/2017     Waterbury   148 CHESTNUT AVE         22180           20000.00000   1.10900      Two Family     Two Family          1
# ...

# %%
# Instances Of Null Values
Estate.isna().sum()
# Out:
# Serial Number            0
# List Year                0
# Month                    0
# Date Recorded            0
# Town                     0
# Address                 49
# Assessed Value           0
# Sales Amount             0
# Sales Ratio              0
# Property Type       381921
# Residential Type    387784
# dtype: int64

# %% [markdown]
# #### In This Project there are alot of Null values which i will not delete or drop with reasons
# ##### 1: From the Property Type and Residence type columns, there are some entries that are Vacant Land, the land are yet to be sold to be sold therefore it is not assigned a residence type or property type.
# ##### 2: Some houses are neither residence, industrial or commercial, but they exists and have addresses that are traceable.

# %%
Estate.head(2)
# Out:
#    Serial Number  List Year  Month Date Recorded     Town          Address  \
# 0        2020348       2020      9    09/13/2021  Ansonia  230 WAKELEE AVE
# 1          20002       2020     10    10/02/2020  Ashford  390 TURNPIKE RD
#
#    Assessed Value  Sales Amount  Sales Ratio Property Type Residential Type
# 0          150500  325000.00000      0.46300    Commercial              NaN
# 1          253000  430000.00000      0.58830   Residential    Single Family

# %% [markdown]
# #### NB: Assessed Value and Sales Ratio are not thesame (Assessed value is assigned to a home or properties for tax purposes), Sales Ratio Value is (Assessed Value/Sales Amount = Sales Ratio).
# #### Therefore it Cannot be sum together but separately.

# %%
# sum of Assessed_value
Assessed_value = Estate['Assessed Value'].sum()

# %%
Assessed_value
# Out:
# 278365691991

# %%
Assessed_value.mean()
# Out:
# 278365691991.0

# %%
# sum of sales ratio
Sales_Ratio = Estate['Sales Ratio'].sum()

# %%
Sales_Ratio
# Out:
# 10417259.588360876

# %%
# Actual sales
Actual_Sales = Estate['Sales Amount'].sum()

# %%
Actual_Sales
# Out:
# 390061045192.6699

# %%
Estate.head(2)
# Out:
#    Serial Number  List Year  Month Date Recorded     Town          Address  \
# 0        2020348       2020      9    09/13/2021  Ansonia  230 WAKELEE AVE
# 1          20002       2020     10    10/02/2020  Ashford  390 TURNPIKE RD
#
#    Assessed Value  Sales Amount  Sales Ratio Property Type Residential Type
# 0          150500  325000.00000      0.46300    Commercial              NaN
# 1          253000  430000.00000      0.58830   Residential    Single Family

# %%
Estate.Town.unique()
# Out:
# array(['Ansonia', 'Ashford', 'Avon', 'Berlin', 'Bethany', 'Bethel',
#        'Bethlehem', 'Bloomfield', 'Branford', 'Bristol', 'Brookfield',
#        'Canaan', 'Canton', 'Cheshire', 'Chester', 'Colchester',
#        'Columbia', 'Cornwall', 'Coventry', 'Cromwell', 'Danbury', 'Derby',
#        'Eastford', 'East Haddam', 'East Haven', 'Farmington', 'Chaplin',
#        'Clinton', 'East Lyme', 'Easton', 'Enfield', 'Essex', 'Durham',
#        'Franklin', 'Glastonbury', 'Hamden', 'Granby', 'Greenwich',
#        'Colebrook', 'East Windsor', 'Griswold', 'Bolton', 'Groton',
#        'Guilford', 'Hartford', 'Harwinton', 'Milford', 'Killingly',
#        'Killingworth', 'Lebanon', 'Lisbon', 'Litchfield', 'Lyme',
#        'Manchester', 'Putnam', 'Norwalk', 'Stafford', 'Mansfield',
#        'Sherman', 'Meriden', 'Stratford', 'Roxbury', 'Oxford', 'Old Lyme',
#        'Norwich', 'Sharon', 'Monroe', 'Tolland', 'Torrington',
#        'Naugatuck', 'Ridgefield', 'New London', 'New Britain', 'Orange',
# ...

# %%
# Sales by Towns
Town_sales = Estate[['Town', 'Sales Amount']]

# %%
Town_sales
# Out:
#                  Town  Sales Amount
# 0             Ansonia  325000.00000
# 1             Ashford  430000.00000
# 2                Avon  179900.00000
# 3                Avon  890000.00000
# 4                Avon 1447500.00000
# ...               ...           ...
# 997206     New London   53100.00000
# 997207      Waterbury   76000.00000
# 997208  Windsor Locks  210000.00000
# 997209     Middletown  280000.00000
# 997210        Milford 7450000.00000
#
# [997211 rows x 2 columns]

# %%
# Total sales generated by town
Town_total_sales = Estate[['Town', 'Sales Amount']]
Town_total_sales = Estate.groupby('Town')[['Assessed Value', 'Sales Amount']].agg('sum')

# %%
Town_total_sales
Town_total_sales.sort_values(['Assessed Value', 'Sales Amount'], ascending =False)
# Out:
#                Assessed Value      Sales Amount
# Town
# Greenwich         43139098563 36018599422.28000
# Stamford          15921788996 28503055642.00000
# Norwalk           11342603458 14347472575.00000
# Bridgeport        10381761266  6612374140.00000
# Stratford          8769158486  4740477623.00000
# ...                       ...               ...
# Hartland             60152933    88655564.00000
# Eastford             58507260   113909822.00000
# Scotland             51916480    77769984.00000
# Union                31161090    52046506.00000
# ***Unknown***           66540      282450.00000
#
# [170 rows x 2 columns]

# %% [markdown]
# ### Total Revenues Generated by Town

# %%
High_sales = Town_total_sales.sort_values(['Assessed Value', 'Sales Amount'], ascending =False)

# %%
High_sales.head(20)
# Out:
#                Assessed Value      Sales Amount
# Town
# Greenwich         43139098563 36018599422.28000
# Stamford          15921788996 28503055642.00000
# Norwalk           11342603458 14347472575.00000
# Bridgeport        10381761266  6612374140.00000
# Stratford          8769158486  4740477623.00000
# Westport           7895480694 12806596085.85000
# Fairfield          7370998996 11136784058.32000
# New Canaan         6960831667  9488582914.00000
# Darien             6257124525 10043331332.00000
# Danbury            4615517546  7874556154.32000
# West Hartford      4156934068  7061730435.84000
# Hamden             4102684797  4333908964.00000
# Milford            4010051398  6144357881.62000
# Ridgefield         3897983013  5905633655.00000
# New Haven          3619181366  5820626604.00000
# Glastonbury        3149504623  4797459901.00000
# Waterbury          3097084876  4760474965.00000
# Wilton             3016370185  4817176257.62000
# ...

# %%
# Average Sales
High_sales.groupby('Town').mean()
# Out:
#                 Assessed Value     Sales Amount
# Town
# ***Unknown***      66540.00000     282450.00000
# Andover        120467950.00000  195661332.95000
# Ansonia        580433098.00000  899950523.97000
# Ashford        172812810.00000  285367647.03000
# Avon          2081212885.00000 3255558971.00000
# ...                        ...              ...
# Windsor Locks  633116792.00000 1113043222.00000
# Wolcott        691263086.00000 1063405154.00000
# Woodbridge     759022847.00000 1136752426.00000
# Woodbury       689809889.00000 1107881437.00000
# Woodstock      423162800.00000  681192018.02000
#
# [170 rows x 2 columns]

# %% [markdown]
# ### Revenues By List Years

# %%
Estate.groupby('List Year')[['Sales Amount']].sum()
# Out:
#                Sales Amount
# List Year
# 2001      14671668335.00000
# 2002      17687185857.00000
# 2003      21020152793.00000
# 2004      31966245823.00000
# 2005      22424983827.00000
# 2006      23191375510.40000
# 2007      15518803446.00000
# 2008      10666103724.00000
# 2009      15100980907.00000
# 2010      11107540414.00000
# 2011      12167673424.00000
# 2012      14226518439.22000
# 2013      16517079160.00000
# 2014      19895675672.67000
# 2015      16135823472.00000
# 2016      25272800660.00000
# 2017      17968045819.66000
# 2018      19458446161.20000
# 2019      24778187646.50000
# 2020      40285754101.02000

# %%
Estate.head(2)
# Out:
#    Serial Number  List Year  Month Date Recorded     Town          Address  \
# 0        2020348       2020      9    09/13/2021  Ansonia  230 WAKELEE AVE
# 1          20002       2020     10    10/02/2020  Ashford  390 TURNPIKE RD
#
#    Assessed Value  Sales Amount  Sales Ratio Property Type Residential Type
# 0          150500  325000.00000      0.46300    Commercial              NaN
# 1          253000  430000.00000      0.58830   Residential    Single Family

# %% [markdown]
# ## Property Types Names

# %%
Estate['Property Type'].unique()
# Out:
# array(['Commercial', 'Residential', 'Vacant Land', nan, 'Apartments',
#        'Condo', 'Industrial', 'Public Utility', 'Two Family',
#        'Three Family', 'Single Family', 'Four Family', 'condo'],
#       dtype=object)

# %% [markdown]
# ### Property Types Counts

# %%
Estate['Property Type'].count()
# Out:
# 615290

# %% [markdown]
# ### Sales By Property Type

# %%
Estate.groupby('Property Type')[['Sales Amount']].sum()
# Out:
#                      Sales Amount
# Property Type
# Apartments       6237473199.00000
# Commercial       3548016954.03000
# Condo           27438220779.57000
# Four Family       679265240.00000
# Industrial        456977530.00000
# Public Utility      1848544.00000
# Residential     29195955859.39000
# Single Family  156039144284.48999
# Three Family     2263523081.00000
# Two Family       5256261988.81000
# Vacant Land       935304076.60000
# condo                 61500.00000

# %% [markdown]
# ## Numbers of Vacant Land

# %%
Vacant_Land = Estate[Estate['Property Type'] == 'Vacant Land']
Vacant_Land
# Out:
#        Serial Number  List Year  Month Date Recorded        Town  \
# 26            200268       2020      7    07/09/2021  Colchester
# 28            200024       2020     11    11/09/2020    Columbia
# 32            200039       2020     11    11/06/2020    Coventry
# 34            200077       2020     12    12/08/2020    Cromwell
# 45             20013       2020     12    12/16/2020    Eastford
# ...              ...        ...    ...           ...         ...
# 66697        2020148       2020      3    03/15/2021     Tolland
# 66732          20275       2020      8    08/19/2021    Thompson
# 66738         200296       2020     12    12/23/2020  Torrington
# 66791          20317       2020      9    09/10/2021  Winchester
# 66804        2020138       2020      3    03/15/2021     Tolland
#
#                   Address  Assessed Value  Sales Amount  Sales Ratio  \
# 26           347 CABIN RD          104000  350000.00000      0.29710
# ...

# %% [markdown]
# ## Sum of Vacant Land

# %%
Vacant_Land.sum()
# Out:
# Serial Number                                             13045352546
# List Year                                                     6389260
# Month                                                           20192
# Date Recorded       07/09/202111/09/202011/06/202012/08/202012/16/...
# Town                ColchesterColumbiaCoventryCromwellEastfordEast...
# Address             347 CABIN RDWEBSTER LANE2075 MAIN ST60 NORTH R...
# Assessed Value                                              367172870
# Sales Amount                                          935304076.60000
# Sales Ratio                                                3437.19689
# Property Type       Vacant LandVacant LandVacant LandVacant LandVa...
# Residential Type                                                    0
# dtype: object

# %% [markdown]
# ## Count of Vacant Land

# %%
Vacant_Land.value_counts
# Out:
# <bound method DataFrame.value_counts of        Serial Number  List Year  Month Date Recorded        Town  \
# 26            200268       2020      7    07/09/2021  Colchester
# 28            200024       2020     11    11/09/2020    Columbia
# 32            200039       2020     11    11/06/2020    Coventry
# 34            200077       2020     12    12/08/2020    Cromwell
# 45             20013       2020     12    12/16/2020    Eastford
# ...              ...        ...    ...           ...         ...
# 66697        2020148       2020      3    03/15/2021     Tolland
# 66732          20275       2020      8    08/19/2021    Thompson
# 66738         200296       2020     12    12/23/2020  Torrington
# 66791          20317       2020      9    09/10/2021  Winchester
# 66804        2020138       2020      3    03/15/2021     Tolland
#
#                   Address  Assessed Value  Sales Amount  Sales Ratio  \
# 26           347 CABIN RD          104000  350000.00000      0.29710
# ...

# %% [markdown]
# ## Vacant Land Prices by List Years

# %%
Vacant_Land[['List Year','Town', 'Assessed Value','Sales Amount','Sales Ratio']].head(20)
# Out:
#      List Year           Town  Assessed Value  Sales Amount  Sales Ratio
# 26        2020     Colchester          104000  350000.00000      0.29710
# 28        2020       Columbia           60300   75000.00000      0.80400
# 32        2020       Coventry           43700   25000.00000      1.74800
# 34        2020       Cromwell          174650  259000.00000      0.67430
# 45        2020       Eastford            2200   20000.00000      0.11000
# 46        2020    East Haddam           51690   65000.00000      0.79520
# 53        2020      East Lyme          170660  220000.00000      0.77570
# 58        2020         Easton          165400  300000.00000      0.55130
# 69        2020          Essex            5600    5000.00000      1.12000
# 71        2020     Farmington          167190  225000.00000      0.74300
# 81        2020         Granby           87290  115000.00000      0.75900
# 82        2020      Greenwich         1061900 2195000.00000      0.48370
# ...

# %% [markdown]
# ### Observation: The dataset has no account on Vacant Land sold only Assessed value, sales amount and sales ratio prices are recorded

# %% [markdown]
# ## When House Residence Type is Industrial

# %%
Industrial = Estate[Estate['Property Type'] == 'Industrial']
Industrial
# Out:
#        Serial Number  List Year  Month Date Recorded           Town  \
# 805           200568       2020      6    06/16/2021       Branford
# 1037       200000254       2020      5    05/07/2021     Brookfield
# 1467         2000374       2020      9    09/07/2021     Bloomfield
# 1470         2000257       2020      6    06/03/2021     Bloomfield
# 1537          201207       2020      7    07/14/2021        Danbury
# ...              ...        ...    ...           ...            ...
# 65584         200914       2020      6    06/10/2021  West Hartford
# 65694          20279       2020      8    08/23/2021       Thompson
# 66150         201323       2020      3    03/29/2021      Waterbury
# 66419       20201368       2020      9    09/24/2021      Stratford
# 66599         200403       2020      6    06/04/2021        Windsor
#
#                           Address  Assessed Value   Sales Amount  Sales Ratio  \
# ...

# %%
Industrial.count()
# Out:
# Serial Number       228
# List Year           228
# Month               228
# Date Recorded       228
# Town                228
# Address             228
# Assessed Value      228
# Sales Amount        228
# Sales Ratio         228
# Property Type       228
# Residential Type      0
# dtype: int64

# %%
Industrial[['List Year','Town', 'Assessed Value','Sales Amount','Sales Ratio']]
# Out:
#        List Year           Town  Assessed Value   Sales Amount  Sales Ratio
# 805         2020       Branford          235500   520000.00000      0.45280
# 1037        2020     Brookfield          157150   620000.00000      0.25347
# 1467        2020     Bloomfield          241710   200000.00000      1.20855
# 1470        2020     Bloomfield          534030   632989.00000      0.84360
# 1537        2020        Danbury         9529200 15774500.00000      0.60400
# ...          ...            ...             ...            ...          ...
# 65584       2020  West Hartford         1439830  2800000.00000      0.51420
# 65694       2020       Thompson          567300   907775.00000      0.62490
# 66150       2020      Waterbury          136350   399000.00000      0.34170
# 66419       2020      Stratford         1409170  8000000.00000      0.17610
# 66599       2020        Windsor         1016540  1573064.00000      0.64620
#
# [228 rows x 5 columns]

# %% [markdown]
# ## Monthly Sales By Industrial Property Type

# %%
Industrial.groupby('Month')[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
#        Assessed Value   Sales Amount  Sales Ratio
# Month
# 1            15423296 14310500.00000    168.38933
# 2            22772850 59210000.00000      7.36534
# 3            12030306 12551775.00000     19.58315
# 4            12584870 18208000.00000     17.84755
# 5            36732710 28630044.00000     19.37366
# 6            38050877 88137874.00000     21.63303
# 7            39793870 70505000.00000     15.63376
# 8            14088230 29772350.00000     14.76539
# 9            19479480 22411400.00000     77.13425
# 10           36975620 57540600.00000     15.25440
# 11           19563910 48910487.00000     15.54047
# 12            5645660  6789500.00000     16.73017

# %% [markdown]
# #### Industrial Property type has record for only 2020

# %%
N_Industrial = Industrial.groupby('Month')[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()

# %%
N_Industrial.plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Month'>

# %%
Estate['Property Type'].unique()
# Out:
# array(['Commercial', 'Residential', 'Vacant Land', nan, 'Apartments',
#        'Condo', 'Industrial', 'Public Utility', 'Two Family',
#        'Three Family', 'Single Family', 'Four Family', 'condo'],
#       dtype=object)

# %% [markdown]
# ## When The House Type is Commercial

# %%
Commercial = Estate[Estate['Property Type'] == 'Commercial']
Commercial
# Out:
#         Serial Number  List Year  Month Date Recorded           Town  \
# 0             2020348       2020      9    09/13/2021        Ansonia
# 8              200097       2020      6    06/04/2021        Bethany
# 13             200804       2020      9    09/28/2021       Branford
# 29             200074       2020      9    09/01/2021       Cornwall
# 31             200282       2020      7    07/15/2021       Coventry
# ...               ...        ...    ...           ...            ...
# 108405          10015       2001     10    10/02/2001       Trumbull
# 109018          10015       2001     10    10/24/2001       Old Lyme
# 110341          10015       2001     11    11/01/2001         Somers
# 110407          10015       2001     11    11/13/2001  Windsor Locks
# 110483          10015       2001     10    10/23/2001      Woodstock
#
#                   Address  Assessed Value  Sales Amount  Sales Ratio  \
# ...

# %% [markdown]
# ### Revenue Generated by commercial Houses in 2020 and 2001

# %%
Commercial.groupby('List Year')[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
#            Assessed Value     Sales Amount  Sales Ratio
# List Year
# 2001              2335110    4237206.00000     13.98693
# 2020           2724579314 3543779748.03000   8526.41658

# %%
Commercial['List Year'].unique()
# Out:
# array([2020, 2001], dtype=int64)

# %%
Commercial.groupby(['List Year','Month'])[['Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
#                  Assessed Value    Sales Amount  Sales Ratio
# List Year Month
# 2001      1               74430    125000.00000      0.59544
#           2               27700    212500.00000      0.13035
#           10            1727880   2899956.00000      9.59007
#           11             505100    999750.00000      3.67106
# 2020      1           183663413 205179739.00000    707.18988
#           2            71415666  88084872.00000    224.26378
#           3           286565126 321914399.03000    824.59100
#           4           242997919 394625283.00000    555.10057
#           5           244771793 191803632.00000    765.86222
#           6           222140727 325045528.00000    796.13095
#           7           370214888 592033578.00000    906.47380
#           8           273627286 327833382.00000    792.93330
#           9           141236873 203576109.00000   1243.74495
#           10          250252364 246521772.00000   1252.04214
# ...

# %%
N_Commercial = Commercial.groupby(['List Year','Month'])[['Assessed Value','Sales Amount','Sales Ratio']].sum()
N_Commercial.plot(kind='line', figsize =(14,6))
# Out:
# <Axes: xlabel='List Year,Month'>

# %% [markdown]
# ### Commercial has record for 2020 and 2001

# %% [markdown]
# ### When the Property type is Apartments

# %%
Apartments  = Estate[Estate['Property Type'] == 'Apartments']
Apartments
# Out:
#        Serial Number  List Year  Month Date Recorded         Town  \
# 109            20899       2020      6    06/21/2021     Hartford
# 115           200230       2020      4    04/26/2021    Killingly
# 158            20761       2020      5    05/28/2021  New Britain
# 426            20847       2020      6    06/07/2021     Hartford
# 700           201339       2020      9    09/20/2021      Bristol
# ...              ...        ...    ...           ...          ...
# 66527         202448       2020      9    09/03/2021    Waterbury
# 66530         200326       2020      4    04/26/2021       Vernon
# 66618       20020016       2020      2    02/22/2021     Woodbury
# 66641         201002       2020      1    01/28/2021    Waterbury
# 66710         200835       2020      7    07/12/2021   Torrington
#
#                               Address  Assessed Value   Sales Amount  \
# 109                       159 RUSS ST          137270   278500.00000
# ...

# %%
# Numbers of list year records in apartments
Apartments['List Year'].unique()
# Out:
# array([2020], dtype=int64)

# %%
Apartments.groupby('Month')[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
#        Assessed Value     Sales Amount  Sales Ratio
# Month
# 1            51822420   87132160.00000     24.04360
# 2            53563810   95509190.00000     14.87209
# 3            62516645  124977794.00000     21.60595
# 4            35863407   69041115.00000     21.44628
# 5            93582100  177303028.00000     31.80698
# 6            44863033   96071500.00000     26.65739
# 7            38465220  174429145.00000     39.39483
# 8            85596790 5145063259.00000     32.22027
# 9            39520777   84941010.00000     28.55412
# 10            9362880   15515650.00000     16.41649
# 11            9089520   23688455.00000     12.24985
# 12           60866451  143800893.00000     17.26609

# %%
N_Apartments = Apartments.groupby('Month')[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
N_Apartments.plot(kind ='line',figsize =(16,10))
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# ### When property Type is condo

# %%
Condo =Estate[Estate['Property Type'] == 'Condo']
Condo
# Out:
#         Serial Number  List Year  Month Date Recorded          Town  \
# 146             10015       2001     11    11/09/2001        Sharon
# 189             10020       2001     10    10/02/2001    West Haven
# 67070           60228       2006      7    07/05/2007        Bethel
# 67075           60075       2006      4    04/05/2007         Essex
# 67080           60416       2006      5    05/25/2007     Newington
# ...               ...        ...    ...           ...           ...
# 997166        1900695       2019      2    02/24/2020      Stamford
# 997169         190079       2019      3    03/06/2020      Prospect
# 997175         190285       2019      5    05/18/2020  Wethersfield
# 997189         190095       2019     12    12/09/2019       Windsor
# 997197         190159       2019     12    12/13/2019   Wallingford
#
#                         Address  Assessed Value  Sales Amount  Sales Ratio  \
# ...

# %%
Condo.groupby('Month')[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
#        Assessed Value     Sales Amount  Sales Ratio
# Month
# 1          1005950394 1483001985.74000   5429.28502
# 2           847243454 1245087552.10000   4854.54704
# 3          1202064390 1693346403.77000   6678.20604
# 4          1350429298 1898313678.26000   7003.12718
# 5          1632439774 2814572007.86000  10566.76089
# 6          1877565841 2666948552.67000   8651.35165
# 7          1718602766 2638669742.86000   8284.14708
# 8          2839350948 2487495924.04000   9355.39897
# 9          1687507126 2145394635.00000   7867.06018
# 10         1527770722 2300634749.08000   7945.21812
# 11         1333775195 1892822986.22000   6743.44568
# 12         1385769575 4171932561.97000   7299.54465

# %%
# Condo Houses by List Year and Month
Condo.groupby(['List Year','Month'])[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
#                  Assessed Value    Sales Amount  Sales Ratio
# List Year Month
# 2001      2               33000     58900.00000      0.56027
#           4               61000    140000.00000      0.43571
#           10            2503000   4532300.00000     11.64452
#           11             125830    194000.00000      2.94256
#           12             423050   1180900.00000      1.58636
# ...                         ...             ...          ...
# 2019      8           288308129 284080372.51000    948.30621
#           9           352524731 296551553.00000   1086.12107
#           10          130077864 208678738.00000    676.15466
#           11          111218700 176724349.00000    571.61906
#           12          142750338 247255925.97000    610.96439
#
# [173 rows x 3 columns]

# %%
# Quick Statistical View of Houses
Condo.describe()
# Out:
#          Serial Number    List Year        Month  Assessed Value  \
# count     105458.00000 105458.00000 105458.00000    105458.00000
# mean      354338.46400   2012.84382      6.85266    174557.35443
# std      6431827.47769      4.22281      3.23571   2776498.59520
# min          817.00000   2001.00000      1.00000         0.00000
# 25%        70488.25000   2009.00000      4.00000     74550.00000
# 50%       130085.00000   2013.00000      7.00000    114240.00000
# 75%       170129.00000   2016.00000     10.00000    179280.00000
# max   1710011174.00000   2019.00000     12.00000 881510000.00000
#
#         Sales Amount  Sales Ratio
# count   105458.00000 105458.00000
# mean    260181.50145      0.85985
# std     663187.71249      7.16571
# min          0.00000      0.00000
# 25%     112500.00000      0.58702
# 50%     175000.00000      0.68610
# 75%     285000.00000      0.81000
# max   39885000.00000   2106.69667

# %%
#Totol count of condo houses
Condo['Property Type'].count()
# Out:
# 105458

# %% [markdown]
# ### When Property Type is Public Utility

# %%
Public_Utility=Estate[Estate['Property Type'] == 'Public Utility']
Public_Utility
# Out:
#        Serial Number  List Year  Month Date Recorded        Town  \
# 4280        20000275       2020      9    09/20/2021      Granby
# 13684         201322       2020      9    09/01/2021    Griswold
# 32215          20049       2020     11    11/16/2020  Plainfield
# 55247          20193       2020      5    05/26/2021    Thompson
# 56950          20412       2020      5    05/26/2021   Waterford
#
#                     Address  Assessed Value  Sales Amount  Sales Ratio  \
# 4280         30 FIRETOWN RD          154210  315000.00000      0.48950
# 13684        29 RICHARD AVE           34510 1400000.00000      0.02465
# 32215       45 SPAULDING RD          117920   39000.00000      3.02359
# 55247              0 NEW RD           42200   59950.00000      0.70390
# 56950  296 WILLETTS AVE EXT           18490   34594.00000      0.53449
#
#         Property Type Residential Type
# 4280   Public Utility              NaN
# 13684  Public Utility              NaN
# ...

# %%
# Count of public Utility
Public_Utility['Property Type'].count()
# Out:
# 5

# %%
# Revenue Generated By Public Utility
Public_Utility[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
# Assessed Value    367330.00000
# Sales Amount     1848544.00000
# Sales Ratio            4.77613
# dtype: float64

# %% [markdown]
# ### When Property Type is For Two Family

# %%
 Two_Family=Estate[Estate['Property Type'] == 'Two Family']
Two_Family
# Out:
#         Serial Number  List Year  Month Date Recorded           Town  \
# 67183           60215       2006     12    12/27/2006        Norwich
# 68039          170378       2017      5    05/04/2018        Windsor
# 380674          60324       2006     10    10/26/2006         Hamden
# 380732          62276       2006      8    08/08/2007     Bridgeport
# 380772          60197       2006      7    07/02/2007   East Windsor
# ...               ...        ...    ...           ...            ...
# 997088         190143       2019     11    11/25/2019  West Hartford
# 997089         190306       2019      6    06/17/2020       Simsbury
# 997122         190442       2019      2    02/11/2020      New Haven
# 997136         190027       2019     10    10/31/2019  Windsor Locks
# 997198         190100       2019     11    11/01/2019      New Haven
#
#                       Address  Assessed Value  Sales Amount  Sales Ratio  \
# ...

# %%
Two_Family.groupby(['List Year','Month'])[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
#                  Assessed Value   Sales Amount  Sales Ratio
# List Year Month
# 2006      1            24944614 47524983.00000    132.80528
#           2            21375040 40981558.00000     83.67898
#           3            25743975 47391152.00000     99.15573
#           4            22555372 41922260.00000     95.24858
#           5            24363633 41532212.00000    203.34105
# ...                         ...            ...          ...
# 2019      8            41145128 64472836.00000    173.26328
#           9            39740295 71996794.00000    172.64157
#           10           32393800 50582214.00000    191.04279
#           11           34618755 53885420.00000    198.82611
#           12           31942915 50872984.00000    161.12581
#
# [168 rows x 3 columns]

# %%
# Count of Two Families House Type
Two_Family['Property Type'].count()
# Out:
# 26407

# %%
# Revenue Generated By Two Families House type
Two_Family[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
# Assessed Value   4029263086.00000
# Sales Amount     5256261988.81000
# Sales Ratio           32032.26444
# dtype: float64

# %% [markdown]
# ### When Property Type is For Three Family

# %%
Three_Family =Estate[Estate['Property Type'] == 'Three Family']
Three_Family
# Out:
#         Serial Number  List Year  Month Date Recorded        Town  \
# 67619          130602       2013      2    02/25/2014  Bridgeport
# 380852          62485       2006      9    09/11/2007  Bridgeport
# 381093          62418       2006      8    08/30/2007  Bridgeport
# 381094          60246       2006     10    10/31/2006  Bridgeport
# 381202          62509       2006      9    09/14/2007  Bridgeport
# ...               ...        ...    ...           ...         ...
# 997046         190150       2019      2    02/21/2020  New London
# 997094         190950       2019      9    09/15/2020     Meriden
# 997179         190389       2019      3    03/24/2020     Norwich
# 997181         190152       2019     11    11/01/2019   Waterbury
# 997201         190302       2019     11    11/29/2019   Waterbury
#
#                      Address  Assessed Value  Sales Amount  Sales Ratio  \
# 67619   102 REMINGTON STREET          206740   50000.00000      4.13480
# ...

# %%
Three_Family.groupby(['List Year','Month'])[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
#                  Assessed Value   Sales Amount  Sales Ratio
# List Year Month
# 2006      1            13323089 23938671.00000     75.05023
#           2             8205587 16385068.00000     37.91967
#           3             9718766 20334931.00000     42.54142
#           4             8438971 18906928.00000     34.67541
#           5            12432729 23795789.00000     77.23358
# ...                         ...            ...          ...
# 2019      8            13211700 26545590.00000     61.88939
#           9            21696263 43251371.00000     97.38849
#           10           13929095 25615956.00000    128.09976
#           11           13767550 26778360.00000     70.65962
#           12           14451065 27326964.00000     66.24845
#
# [168 rows x 3 columns]

# %%
# Count of Three Families House Type
Three_Family['Property Type'].count()
# Out:
# 12586

# %%
# Revenue Generated By Three Families House type
Three_Family[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
# Assessed Value   1720702255.00000
# Sales Amount     2263523081.00000
# Sales Ratio           18176.14655
# dtype: float64

# %% [markdown]
# ### When Property Type is For Single family

# %%
Single_Family =Estate[Estate['Property Type'] == 'Single Family']
Single_Family
# Out:
#         Serial Number  List Year  Month Date Recorded           Town  \
# 67926          160369       2016      6    06/28/2017       Trumbull
# 67927          160106       2016      9    09/05/2017      Thomaston
# 72886           10020       2001     10    10/24/2001        Madison
# 73454           10020       2001      2    02/01/2002      Colebrook
# 73830           10020       2001     10    10/10/2001       Cheshire
# ...               ...        ...    ...           ...            ...
# 997205         190272       2019      8    08/03/2020         Wilton
# 997206         190272       2019      6    06/24/2020     New London
# 997207         190284       2019     11    11/27/2019      Waterbury
# 997208         190129       2019      4    04/27/2020  Windsor Locks
# 997209         190504       2019      6    06/03/2020     Middletown
#
#                    Address  Assessed Value  Sales Amount  Sales Ratio  \
# ...

# %%
Single_Family.groupby(['List Year','Month'])[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
#                  Assessed Value     Sales Amount  Sales Ratio
# List Year Month
# 2001      1              127960     168000.00000      2.03709
#           2              152140     191025.00000      3.00353
#           3               92400     280000.00000      0.33000
#           10            3590331    5607250.00000     22.00319
#           11             895100    1306650.00000      6.27628
# ...                         ...              ...          ...
# 2019      8          1677613986 2604899727.00000   3418.70405
#           9          1558501284 2447775328.66000   3454.73999
#           10          816064773 1173969020.03000   2633.67126
#           11          764079463 1066807588.02000   2806.11652
#           12          822974844 1123360056.94000   2862.34917
#
# [174 rows x 3 columns]

# %%
# Count of single Families House Type
Single_Family['Property Type'].count()
# Out:
# 401664

# %%
# Revenue Generated By single Families House type
Single_Family[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
# Assessed Value   111305366146.00000
# Sales Amount     156039144284.49002
# Sales Ratio           3259151.11881
# dtype: float64

# %% [markdown]
# ### When Property type is For Four family

# %%
 Four_Family =Estate[Estate['Property Type'] == 'Four Family']
Four_Family
# Out:
#         Serial Number  List Year  Month Date Recorded         Town  \
# 95314           10015       2001     12    12/04/2001         Kent
# 95770           10015       2001     10    10/01/2001       Vernon
# 96395           10015       2001     10    10/11/2001     Cromwell
# 97282           10015       2001     11    11/15/2001   Washington
# 97780           10015       2001      1    01/01/2002      Roxbury
# ...               ...        ...    ...           ...          ...
# 996054         190242       2019     12    12/16/2019  New Britain
# 996196         190120       2019      3    03/20/2020     Plymouth
# 996311         190031       2019     10    10/04/2019    Waterbury
# 996338          19088       2019     11    11/06/2019   West Haven
# 997135         190097       2019      2    02/10/2020     Plymouth
#
#                    Address  Assessed Value  Sales Amount  Sales Ratio  \
# 95314         SEGAR MTN RD               0    2213.00000      0.00000
# ...

# %%
Four_Family.groupby(['List Year','Month'])[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
#                  Assessed Value    Sales Amount  Sales Ratio
# List Year Month
# 2001      1               68780    236500.00000      0.56757
#           10            1688238   2401300.00000     42.14740
#           11             266900    575500.00000      2.01081
#           12             185060    326213.00000      1.11714
# 2006      1              878380   1833000.00000      2.89648
# ...                         ...             ...          ...
# 2019      8             2061650 159734200.00000      7.40532
#           9             6310963  11784500.00000     38.95940
#           10            5573940   9732528.00000     22.06979
#           11            5305070   8557799.00000     33.90845
#           12            4738270   8798800.00000     15.97125
#
# [172 rows x 3 columns]

# %%
# Count of Four Families House Type
Four_Family['Property Type'].count()
# Out:
# 2172

# %%
# Revenue Generated By Four Families House type
Four_Family[[ 'Assessed Value','Sales Amount','Sales Ratio']].sum()
# Out:
# Assessed Value   402407699.00000
# Sales Amount     679265240.00000
# Sales Ratio           3102.56264
# dtype: float64
